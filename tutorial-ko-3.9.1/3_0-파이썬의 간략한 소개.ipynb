# %%
# 3. 파이썬의 간략한 소개
# https://docs.python.org/ko/3/tutorial/introduction.html

# %%
# this is the first comment
spam = 1
text = "#This is not a comment because it's inside quotes"

# %%
# 3.1. 파이썬을 계산기로 사용하기

# %% [markdown]
# 다음 내용은 `3.1.1. 숫자`로 이어짐.
