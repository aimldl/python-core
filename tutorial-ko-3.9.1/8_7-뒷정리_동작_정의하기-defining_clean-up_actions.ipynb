# %% [markdown]
# # 8.7. 뒷정리 동작 정의하기 (Defining Clean-up Actions)
# * https://docs.python.org/ko/3.9/tutorial/errors.html#defining-clean-up-actions
# * https://docs.python.org/3.9/tutorial/errors.html#defining-clean-up-actions

# %% [markdown]
# TODO: https://docs.python.org/ko/3.9/tutorial/errors.html#defining-clean-up-actions
