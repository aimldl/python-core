# %% [markdown]
# # Python » Korean » 3.9.1 » Documentation » 파이썬 자습서
# https://docs.python.org/ko/3.9/tutorial/index.html
#
#
# 파이썬 이라는 이름은 《Monty Python’s Flying Circus》라는 BBC 쇼에서 따온 것이고, 파충류와는 아무런 관련이 없습니다.

# %%
print("hi")
