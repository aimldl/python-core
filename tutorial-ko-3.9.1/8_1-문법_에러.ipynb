# %% [markdown]
# # 8.1. 문법 에러 (Syntax error)
# * https://docs.python.org/ko/3.9/tutorial/errors.html#syntax-errors
#
# 문법 에러는 파싱 에러 (Parsing error)라고도 불립니다.

# %%
while True
    print('Hello, world')
# Out:
#   File "<ipython-input-1-421fc7fbe79b>", line 1
#     while True
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# `SyntaxError`의 원인은 콜론 `:`이 빠져있기 때문입니다.
