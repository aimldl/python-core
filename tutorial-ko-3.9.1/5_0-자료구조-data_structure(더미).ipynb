# %% [markdown]
# # 5. 자료 구조 (Data Structure)
# * [5. 자료 구조](https://docs.python.org/ko/3.9/tutorial/datastructures.html)
# * [5. Data Structures](https://docs.python.org/3.9/tutorial/datastructures.html)
