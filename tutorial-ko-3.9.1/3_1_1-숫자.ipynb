# %%
# 3.1. 파이썬을 계산기로 사용하기
#   3.1.1. 숫자
2+2
# Out:
# 4

# %%
50 - 5*6
# Out:
# 20

# %%
(50 - 5 * 6) / 4
# Out:
# 5.0

# %%
8 /5
# Out:
# 1.6

# %%
# classical division
17 / 3
# Out:
# 5.666666666666667

# %%
# review
# floor division
17 // 3
# Out:
# 5

# %%
# review
# the remainder of the division
# modulo %
17 % 3
# Out:
# 2

# %%
5 * 3 + 2
# Out:
# 17

# %%
# ** 연산자, 거듭제곱 (power)
5 ** 2
# Out:
# 25

# %%
2 ** 7
# Out:
# 128

# %%
# = 변수에 대입
width = 20
height = 5 * 9 
width * height
# Out:
# 900

# %%
# error
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-488b7b155b78> in <module>()
#       1 # error
# ----> 2 n
#
# NameError: name 'n' is not defined

# %%
# 실수 지원
4 * 3.75 - 1
# Out:
# 14.0

# %%
tax = 12.5 / 100
price = 100.50
price * tax
# Out:
# 12.5625

# %%
# review
# _는 마지막에 인쇄된 표현식입니다
price + _
# 100.50 + 12.5625
# Out:
# 113.0625

# %%
round(_, 2)
# Out:
# 113.06

# %% [markdown]
# [숫자 형](https://docs.python.org/ko/3/library/stdtypes.html#typesnumeric)으로 [int](https://docs.python.org/ko/3/library/functions.html#int), [float](https://docs.python.org/ko/3/library/functions.html#float), [complex (복소수)](https://docs.python.org/ko/3/library/functions.html#complex), [Decimal](https://docs.python.org/ko/3/library/decimal.html#decimal.Decimal), [Fraction](https://docs.python.org/ko/3/library/fractions.html#fractions.Fraction) 등도 지원합니다.
