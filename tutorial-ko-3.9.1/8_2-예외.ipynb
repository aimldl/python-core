# %% [markdown]
# # 8.2. 예외
# * https://docs.python.org/ko/3.9/tutorial/errors.html#exceptions
#
# * 실행 중에 감지되는 에러를 예외라고 부릅니다.
# * 예외가 무조건 치명적이지 않습니다.
#
# 예외 처리를 하지 않아서 에러 메세지가 만들어지는 예제입니다.
# * 에러 발생 시 메세지의 마지막 줄에 어떤 일이 일어났는지 알려줍니다.

# %%
10 * (1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-0b280f36835c> in <module>()
# ----> 1 10 * (1/0)
#
# ZeroDivisionError: division by zero

# %%
'2' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-d2b23a1db757> in <module>()
# ----> 1 '2' + 2
#
# TypeError: must be str, not int
