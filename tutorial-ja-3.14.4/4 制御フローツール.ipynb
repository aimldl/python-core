# %% [markdown]
# # [4. その他の制御フローツール](https://docs.python.org/ja/3.14/tutorial/controlflow.html)
#
# ## Let's summarize the before we start.
# * 制御        せいぎょ    コントロール
# * if 文      イフぶん
# * switch 文	 スイッチぶん
# * case 文	ケースぶん
# * match 文	マッチぶん
# * for 文	フォーぶん
# * break    ブレイク
# * continue コンティニュー

# %% [markdown]
# ## [4.1. if 文](https://docs.python.org/ja/3.14/tutorial/controlflow.html#if-statements)

# %% [markdown]
# ## [4.2. for 文](https://docs.python.org/ja/3.14/tutorial/controlflow.html#for-statements)

# %% [markdown]
# ## [4.3. range() 関数](https://docs.python.org/ja/3.14/tutorial/controlflow.html#the-range-function)

# %% [markdown]
# ## [4.4. break 文と continue 文](https://docs.python.org/ja/3.14/tutorial/controlflow.html#break-and-continue-statements)

# %% [markdown]
# TODO: Add the rest of sub-chapters here and add furigana table.

# %% [markdown]
# ## [4.5. ループの else 節](https://docs.python.org/ja/3.14/tutorial/controlflow.html#else-clauses-on-loops)
#
# * if 節（イフせつ）
# * elif 節（エリフせつ）
# * else 節（エルスせつ）
