# %% [markdown]
# ## [3.2. プログラミングへの第一歩](https://docs.python.org/ja/3.14/tutorial/introduction.html#first-steps-towards-programming)

# %% [markdown]
# もっと複雑な課題に Python を使えます:

# %% [markdown]
# TODO
# # 피보나치 수열(Fibonacci series)의 앞부분을 계산
# #   https://ko.wikipedia.org/wiki/%ED%94%BC%EB%B3%B4%EB%82%98%EC%B9%98_%EC%88%98
# #   https://en.wikipedia.org/wiki/Fibonacci_number
